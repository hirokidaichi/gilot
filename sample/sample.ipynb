# %%
import gilot

# %%
# !git clone https://github.com/facebook/react.git repos/react
# Out:
# fatal: destination path 'repos/react' already exists and is not an empty directory.

# %%
df = gilot.from_dir("./repos/react")
df.to_csv("./react.csv")
gilot.plot(df,name="facebook/react GIT LOG REPORT")

# %%
df.describe()
# Out:
#          insertions    deletions         lines       files
# count    662.000000   662.000000    662.000000  662.000000
# mean     231.870091   126.676737    358.546828    7.845921
# std     1079.842373   461.822278   1297.153861   16.415662
# min        0.000000     0.000000      0.000000    0.000000
# 25%        5.000000     2.000000     10.250000    1.000000
# 50%       37.000000    10.000000     60.000000    3.000000
# 75%      143.000000    51.000000    207.000000    7.000000
# max    22052.000000  5588.000000  22052.000000  215.000000

# %%
df.author.value_counts()
# Out:
# Dominic Gannaway      112
# Brian Vaughn          109
# Dan Abramov            99
# Sebastian Markbåge     99
# Andrew Clark           78
#                      ...
# Faelivrinx              1
# Kunuk Nykjær            1
# Laura buns              1
# Ian Obermiller          1
# 伊撒尔                     1
# Name: author, Length: 93, dtype: int64

# %%
df_csv = gilot.from_csv("./react.csv")
df_csv.describe()
# Out:
#          insertions    deletions         lines       files
# count    662.000000   662.000000    662.000000  662.000000
# mean     231.870091   126.676737    358.546828    7.845921
# std     1079.842373   461.822278   1297.153861   16.415662
# min        0.000000     0.000000      0.000000    0.000000
# 25%        5.000000     2.000000     10.250000    1.000000
# 50%       37.000000    10.000000     60.000000    3.000000
# 75%      143.000000    51.000000    207.000000    7.000000
# max    22052.000000  5588.000000  22052.000000  215.000000

# %%
gilot.plot(df_csv,timeslot="1M")
