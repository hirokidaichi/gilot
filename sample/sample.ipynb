# %%
import gilot

# %%
# !git clone https://github.com/facebook/react.git repos/react
# Out:
# fatal: destination path 'repos/react' already exists and is not an empty directory.

# %%
df = gilot.from_dir("./repos/react")
df.to_csv("./react.csv")
gilot.plot(df,name="facebook/react GIT LOG REPORT")

# %%
df.describe()
# Out:
#          insertions    deletions         lines       files
# count    676.000000   676.000000    676.000000  676.000000
# mean     232.073964   127.392012    359.465976    7.823964
# std     1069.197861   457.868167   1285.144552   16.289331
# min        0.000000     0.000000      0.000000    0.000000
# 25%        5.000000     2.000000     11.000000    1.000000
# 50%       38.000000    10.000000     63.500000    3.000000
# 75%      148.000000    55.000000    213.750000    8.000000
# max    22052.000000  5588.000000  22052.000000  215.000000

# %%
df.author.value_counts()
# Out:
# Dominic Gannaway      115
# Brian Vaughn          110
# Sebastian Markbåge    104
# Dan Abramov            99
# Andrew Clark           80
#                      ...
# Richard Maisano         1
# Chang Yan               1
# Faelivrinx              1
# Rodrigo Graça           1
# Christoph Nakazawa      1
# Name: author, Length: 93, dtype: int64

# %%
df_csv = gilot.from_csv("./react.csv")
df_csv.describe()
# Out:
#          insertions    deletions         lines       files
# count    676.000000   676.000000    676.000000  676.000000
# mean     232.073964   127.392012    359.465976    7.823964
# std     1069.197861   457.868167   1285.144552   16.289331
# min        0.000000     0.000000      0.000000    0.000000
# 25%        5.000000     2.000000     11.000000    1.000000
# 50%       38.000000    10.000000     63.500000    3.000000
# 75%      148.000000    55.000000    213.750000    8.000000
# max    22052.000000  5588.000000  22052.000000  215.000000

# %%
gilot.plot(df_csv,timeslot="1M")
